# %% [markdown]
# # 04 Dashboard Data Preparation
# Final aggregation and export for Power BI or Tableau.

# %%
import pandas as pd
dashboard_df = pd.read_csv('../dashboard/powerbi_or_tableau_data.csv')
print(f"Final Dataset Columns: {len(dashboard_df.columns)}")
dashboard_df.head()

# %% [markdown]
# ## Visualizing Final KPI data

# %%
print("Top 5 Majors by Risk Score:")
dashboard_df.groupby('major')['at_risk_score'].mean().sort_values(ascending=False).head(5)
