# %% [markdown]
# # 03 Student Risk Analysis
# Identifying high-risk students based on multi-factor scoring.

# %%
import pandas as pd
risk_df = pd.read_csv('../data/processed/student_risk_analysis.csv')

# Risk Distribution
risk_counts = risk_df['risk_category'].value_counts()
risk_counts.plot(kind='pie', autopct='%1.1f%%', colors=['#ff9999','#66b3ff','#99ff99'])
plt.title('Risk Category Distribution')
plt.show()

# %% [markdown]
# ## Top High Risk Students

# %%
high_risk = risk_df[risk_df['risk_category'] == 'High Risk'].sort_values('at_risk_score', ascending=False)
print(f"Number of High Risk Students: {len(high_risk)}")
high_risk.head(10)
